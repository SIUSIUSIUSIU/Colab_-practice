# %% [markdown]
# <a href="https://colab.research.google.com/github/SIUSIUSIUSIU/Colab_-practice/blob/main/20220825_%EC%9D%B8%EA%B3%B5%EC%8B%A0%EA%B2%BD%EB%A7%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import e
import numpy as np

# %%
e
# Out:
# 2.718281828459045

# %%
e**-1
# Out:
# 0.36787944117144233

# %%
e**0
# Out:
# 1.0

# %%
X= np.array([
              [0,0],
              [0,1],
              [1,0],
              [1,1] 
        ], dtype="float32")

# %%
X
# Out:
# array([[0., 0.],
#        [0., 1.],
#        [1., 0.],
#        [1., 1.]], dtype=float32)

# %%
y= np.array([
             [0],
             [0],
             [0],
             [1]
    ], dtype="float32")

# %%
y
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [1.]], dtype=float32)

# %%
w= np.array([[1],[2]], dtype="float32")
b= np.array([3], dtype="float32")

# %%
w
# Out:
# array([[1.],
#        [2.]], dtype=float32)

# %%
b
# Out:
# array([3.], dtype=float32)

# %%
np.dot(X,w) # np.dot = 배열끼리 곱하기
# Out:
# array([[0.],
#        [2.],
#        [1.],
#        [3.]], dtype=float32)

# %%
np.dot(X,w)+b
# Out:
# array([[3.],
#        [5.],
#        [4.],
#        [6.]], dtype=float32)

# %%
hypothesis = np.dot(X,w)+b

# %%
hypothesis
# Out:
# array([[3.],
#        [5.],
#        [4.],
#        [6.]], dtype=float32)

# %%
def sigmoid(h):
  return 1/(1 + np.exp(-h)) 
  # 시그모이드 함수 : 0, 1로 return
  # np.exp(-h) : e의 -h 승

# %%
hypothesis = sigmoid(np.dot(X,w)+b)

# %%
hypothesis
# Out:
# array([[0.95257413],
#        [0.9933072 ],
#        [0.98201376],
#        [0.9975274 ]], dtype=float32)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 위 공식을 미분하면 기울기가 나옴

# %%
(hypothesis-y)
# Out:
# array([[ 0.95257413],
#        [ 0.9933072 ],
#        [ 0.98201376],
#        [-0.00247258]], dtype=float32)

# %%
X.T 
# T : 줄칸을 반대로 전환 (트랜포스) 줄 -> 칸
# Out:
# array([[0., 0., 1., 1.],
#        [0., 1., 0., 1.]], dtype=float32)

# %%
X.T[0]
# X의 줄칸을 반대로 전환하고 0번쨰 줄을 리턴
# X.T[0] = x1
# Out:
# array([0., 0., 1., 1.], dtype=float32)

# %%
np.dot(X.T[0], (hypothesis-y)) / 4 # w1의 수정값
# Out:
# array([0.2448853], dtype=float32)

# %%
w1_gred = (np.dot(X.T[0], (hypothesis - y))) / 4

# %%
w1_gred
# Out:
# array([0.2448853], dtype=float32)

# %%
np.dot(X.T[1], (hypothesis-y)) / 4 # w2의 수정값
# Out:
# array([0.24770865], dtype=float32)

# %%
w2_gred = (np.dot(X.T[1], (hypothesis-y))) / 4

# %%
w2_gred
# Out:
# array([0.24770865], dtype=float32)

# %%
b_gred = sum(hypothesis - y) / 4

# %%
b_gred
# Out:
# array([0.7313556], dtype=float32)

# %%
# 예측값
hypothesis = sigmoid(np.dot(X,w)+b)
print("hypothesis=", hypothesis)
# 오차율
cost = -sum(y * np.log(hypothesis) + (1 - y) * np.log(1-hypothesis)) / 4
print("cost=",cost)
w1_gred = (np.dot(X.T[0], (hypothesis - y))) / 4
w2_gred = (np.dot(X.T[1], (hypothesis-y))) / 4
b_gred = sum(hypothesis - y) / 4
print("w1_gred", w1_gred)
print("w2_gred", w2_gred)
print("b_gred", b_gred)
# Out:
# hypothesis= [[0.95257413]
#  [0.9933072 ]
#  [0.98201376]
#  [0.9975274 ]]
# cost= [3.0189826]
# w1_gred [0.2448853]
# w2_gred [0.24770865]
# b_gred [0.7313556]

# %%
for j in range(2):
    # 예측값
    hypothesis = sigmoid(np.dot(X,w)+b)
    print("hypothesis=", hypothesis)
    # 오차율
    cost = -sum(y * np.log(hypothesis) + (1 - y) * np.log(1-hypothesis)) / 4
    print("cost=",cost)
    w_gred = (np.dot(X.T[j], (hypothesis - y))) / 4
    # w2_gred = (np.dot(X.T[1], (hypothesis-y))) / 4
    b_gred = sum(hypothesis - y) / 4
    print("w_gred", w_gred)
    print("b_gred", b_gred)
    print("="*100)
# Out:
# hypothesis= [[0.95257413]
#  [0.9933072 ]
#  [0.98201376]
#  [0.9975274 ]]
# cost= [3.0189826]
# w_gred [0.2448853]
# b_gred [0.7313556]
# ...
# hypothesis= [[0.95257413]
#  [0.9933072 ]
#  [0.98201376]
#  [0.9975274 ]]
# cost= [3.0189826]
# w_gred [0.24770865]
# b_gred [0.7313556]
# ...

# %%
w
# Out:
# array([[1.],
#        [2.]], dtype=float32)

# %%
for j in range(2):
    print("j=", j)
    # 예측값
    hypothesis = sigmoid(np.dot(X,w)+b)
    print("hypothesis=", hypothesis)
    # 오차율
    cost = -sum(y * np.log(hypothesis) + (1 - y) * np.log(1-hypothesis)) / 4
    print("cost=",cost)
    w_gred = (np.dot(X.T[j], (hypothesis - y))) / 4
    # w2_gred = (np.dot(X.T[1], (hypothesis-y))) / 4
    b_gred = sum(hypothesis - y) / 4
    print("w_gred", w_gred)
    print("b_gred", b_gred)
    print("w[j]=",[j])
    w[j]= w[j]-0.1 * w_gred
    print("w[j] 없데이트 값 ",w[j]) 
    print("="*100)
# Out:
# j= 0
# hypothesis= [[0.95257413]
#  [0.9933072 ]
#  [0.98201376]
#  [0.9975274 ]]
# cost= [3.0189826]
# w_gred [0.2448853]
# b_gred [0.7313556]
# w[j]= [0]
# w[j] 없데이트 값  [0.9755115]
# ...
# j= 1
# hypothesis= [[0.95257413]
#  [0.9933072 ]
#  [0.9815761 ]
#  [0.9974662 ]]
# cost= [3.0129871]
# w_gred [0.24769334]
# b_gred [0.73123085]
# w[j]= [1]
# w[j] 없데이트 값  [1.9752307]
# ...

# %%
for i in range(1000):
    print("i=", i)
    for j in range(2):
        print("j=", j)
        # 예측값
        hypothesis = sigmoid(np.dot(X,w)+b)
        print("hypothesis=", hypothesis)
        # 오차율
        cost = -sum(y * np.log(hypothesis) + (1 - y) * np.log(1-hypothesis)) / 4
        print("cost=",cost)
        w_gred = (np.dot(X.T[j], (hypothesis - y))) / 4
        # w2_gred = (np.dot(X.T[1], (hypothesis-y))) / 4
        b_gred = sum(hypothesis - y) / 4
        print("w_gred", w_gred)
        print("b_gred", b_gred)
        print("w[j]=",[j])
        print("b=", b)
        w[j]= w[j]-0.1 * w_gred
        b = b -0.1 * b_gred
        print("b 업데이트 값 ", b)
        print("w[j] 업데이트 값 ",w[j]) 
        print("="*100)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# w[j]= [1]
# b= [-5.1921377]
# b 업데이트 값  [-5.19355]
# w[j] 업데이트 값  [3.297318]
# ...
# i= 815
# j= 0
# hypothesis= [[0.0055216 ]
#  [0.13053551]
#  [0.12542044]
#  [0.794986  ]]
# cost= [0.12721436]
# w_gred [-0.01989839]
# b_gred [0.01411588]
# w[j]= [0]
# b= [-5.19355]
# b 업데이트 값  [-5.1949615]
# w[j] 업데이트 값  [3.2534683]
# ...
# j= 1
# hypothesis= [[0.00551386]
#  [0.13037542]
#  [0.1254839 ]
#  [0.7950802 ]]
# cost= [0.1271549]
# w_gred [-0.0186361]
# b_gred [0.01411334]
# w[j]= [1]
# b= [-5.1949615]
# b 업데이트 값  [-5.196373]
# w[j] 업데이트 값  [3.2991817]
# ...
# i= 816
# j= 0
# hypothesis= [[0.00550612]
#  [0.13042669]
#  [0.12532909]
#  [0.795154  ]]
# cost= [0.12710026]
# w_gred [-0.01987923]
# b_gred [0.01410397]
# w[j]= [0]
# b= [-5.196373]
# b 업데이트 값  [-5.1977835]
# w[j] 업데이트 값  [3.2554562]
# ...
# j= 1
# hypothesis= [[0.00549841]
#  [0.13026682]
#  [0.1253924 ]
#  [0.795248  ]]
# cost= [0.12704092]
# w_gred [-0.0186213]
# b_gred [0.0141014]
# w[j]= [1]
# ...
